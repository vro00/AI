# %%
class Bank:
    __identity = None

    def _init_(self):
        pass

    def generateCustomerID(self, identity):
        self._identity = identity

    def searchCustomer(self, setOfCustomers):

        for currentCustomer in setOfCustomers:
            if (currentCustomer._identity == self._identity):
                return 1

        return 0

    @classmethod
    def presentScheme( cls ):
        print("When Deposit is 2 years : Interest is 5.4%")
        print("When Deposit is 5 years : Interest is 7.4%")
        print("When Deposit is 10 years : Interest is 8.4%")
        print("When Deposit is 15 years : Interest is 11.4%")


flag = 1
setOfCustomers = set()
numberOfCustomer = 1
while (flag == 1):

    print("Press 0 to Exit")
    print("Press 1 for Create a Bank Account")
    print("Press 2 to Search Account")
    print("Press 3 for Term Deposit Plans")

    choice = int(input())
    if (choice == 0):
        flag = 0
    elif (choice == 1):
        currentCustomer = Bank()
        currentCustomer.generateCustomerID(numberOfCustomer)
        numberOfCustomer = numberOfCustomer + 1
        setOfCustomers.add(currentCustomer)
        print("Account Created")
    elif (choice == 2):
        print("Enter Customer ID : ", end="")
        identity = int(input())

        currentCustomer = Bank()
        currentCustomer.generateCustomerID(identity)
        if ( currentCustomer.searchCustomer(setOfCustomers) == 1 ):
            print("Customer Exist")
        else:
            print( "Customer doesn't Exist." )

    elif (choice == 3):
        Bank.presentScheme()

    else:
        flag = 0

print("End of Program")
input()
# Out:
# Press 0 to Exit
# Press 1 for Create a Bank Account
# Press 2 to Search Account
# Press 3 for Term Deposit Plans
# 1
# Account Created
# Press 0 to Exit
# Press 1 for Create a Bank Account
# Press 2 to Search Account
# Press 3 for Term Deposit Plans
# 2
# Enter Customer ID : 2
# Customer doesn't Exist.
# Press 0 to Exit
# Press 1 for Create a Bank Account
# Press 2 to Search Account
# Press 3 for Term Deposit Plans
# 1
# Account Created
# Press 0 to Exit
# Press 1 for Create a Bank Account
# Press 2 to Search Account
# Press 3 for Term Deposit Plans
# 2
# Enter Customer ID : 1
# Customer Exist
# Press 0 to Exit
# Press 1 for Create a Bank Account
# Press 2 to Search Account
# Press 3 for Term Deposit Plans
# 3
# When Deposit is 2 years : Interest is 5.4%
# When Deposit is 5 years : Interest is 7.4%
# When Deposit is 10 years : Interest is 8.4%
# When Deposit is 15 years : Interest is 11.4%
# Press 0 to Exit
# Press 1 for Create a Bank Account
# Press 2 to Search Account
# ...
